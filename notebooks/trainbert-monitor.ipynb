# %%
import numpy as np
import pandas as pd
import gc
import sys
import os
import yaml
import re
import random
import math
import matplotlib.pyplot as plt
import warnings
import pickle
from typing import *
from pathlib import Path
from dataclasses import dataclass, field, asdict
from shutil import copyfile
warnings.simplefilter('ignore')

# %%
@dataclass
class Config:
    outdir: str = "../results/monitor"
    device: str = "cuda:1"
    device_id: int = 1

    datadir: str = '../data/shopee-product-matching'
    modeldir: str = '../models/bert/bert_en_uncased_L-24_H-1024_A-16_1'
    seed: int = 123
    n_splits: int = 5
    
    # Training config
    batch_size: int = 32
    epochs: int = 50
    patience: int = 5
    lr: float = 0.00001

    def update(self, param_dict: Dict) -> "Config":
        # Overwrite by `param_dict`
        for key, value in param_dict.items():
            if not hasattr(self, key):
                raise ValueError(f"[ERROR] Unexpected key for flag = {key}")
            setattr(self, key, value)
        return self
    
    def to_yaml(self, filepath: str, width: int = 120):
        with open(filepath, 'w') as f:
            yaml.dump(asdict(self), f, width=width)

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %%
base_dir = Path().resolve()
sys.path.append(os.path.abspath(base_dir / '../'))

config_dict = {
#     'epochs': 1,
}

config = Config().update(config_dict)
config.to_yaml(base_dir / config.outdir / 'config.yaml')

os.environ["CUDA_VISIBLE_DEVICES"] = str(config.device_id)

from src.tokenization import *
from src.preprocess import *
from src.text import *
from src.model import *

import tensorflow as tf
import tensorflow_hub as hub

# %%
train = pd.read_csv(base_dir / config.datadir / 'train.csv')
train = prepare_dataset(df=train, n_splits=config.n_splits, seed=config.seed)
n_classes = train['label_group'].nunique()
train.head()
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
#
#                                                title  label_group  \
# 0                          Paper Bag Victoria Secret          666
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...         7572
# 2        Maling TTS Canned Pork Luncheon Meat 397 gr         6172
# 3  Daster Batik Lengan pendek - Motif Acak / Camp...        10509
# 4                  Nescafe \xc3\x89clair Latte 220ml         9425
#
#                              matches  fold
# 0   train_129225211 train_2278313361     1
# 1  train_3386243561 train_3423213080     2
# 2  train_2288590299 train_3803689425     4
# 3  train_2406599165 train_3342059966     2
# 4   train_3369186413 train_921438619     4

# %%
for fold in range(config.n_splits):
    seed_everything(config.seed)

    outdir = base_dir / config.outdir / f'fold-{fold}'
    os.makedirs(str(outdir), exist_ok=True)
    
    train_df, valid_df = train.query('fold != @fold'), train.query('fold == @fold')
    
    bert_layer = hub.KerasLayer(str(base_dir / config.modeldir), trainable=True)
    vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
    do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()
    tokenizer = FullTokenizer(vocab_file, do_lower_case)
    
    x_train = bert_encode(train_df['title'].values, tokenizer, max_len=70)
    x_val = bert_encode(valid_df['title'].values, tokenizer, max_len=70)
    y_train = train_df['label_group'].values
    y_val = valid_df['label_group'].values
    
    x_train = (x_train[0], x_train[1], x_train[2], y_train)
    x_val = (x_val[0], x_val[1], x_val[2], y_val)
    
    bert_model = build_bert_model(bert_layer, n_classes=n_classes, lr=config.lr, max_len=70)
    
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        str(outdir / (f'Bert_{config.seed}' + '_epoch{epoch:02d}.h5')),
        monitor = 'val_loss', 
        verbose = 1, 
        save_best_only = False,
        save_weights_only = True, 
        mode = 'min',
        save_freq=2
    )

    
    history = bert_model.fit(
        x_train, y_train,
        validation_data = (x_val, y_val),
        epochs = config.epochs, 
        callbacks = [checkpoint],
        batch_size = config.batch_size,
        verbose = 1
    )
    
    pickle.dump(history.history, open(str(outdir / 'history.pkl'), 'wb'))
    
    del bert_model, bert_layer, train_df, valid_df, x_train, x_val, y_train, y_val
    gc.collect()
    tf.keras.backend.clear_session()
    
    break
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 857/857 [==============================] - 452s 527ms/step - loss: 23.7876 - sparse_categorical_accuracy: 0.0000e+00 - val_loss: 23.1132 - val_sparse_categorical_accuracy: 1.4599e-04
# Epoch 2/50
# 857/857 [==============================] - ETA: 0s - loss: 21.9610 - sparse_categorical_accuracy: 0.0038
# Epoch 00002: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch02.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 21.9610 - sparse_categorical_accuracy: 0.0038 - val_loss: 21.6950 - val_sparse_categorical_accuracy: 0.0067
# Epoch 3/50
# 857/857 [==============================] - 450s 525ms/step - loss: 19.6242 - sparse_categorical_accuracy: 0.0155 - val_loss: 20.4578 - val_sparse_categorical_accuracy: 0.0220
# Epoch 4/50
# 857/857 [==============================] - ETA: 0s - loss: 17.2921 - sparse_categorical_accuracy: 0.0370
# Epoch 00004: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch04.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 17.2921 - sparse_categorical_accuracy: 0.0370 - val_loss: 19.4208 - val_sparse_categorical_accuracy: 0.0382
# Epoch 5/50
# 857/857 [==============================] - 450s 525ms/step - loss: 15.1203 - sparse_categorical_accuracy: 0.0655 - val_loss: 18.6209 - val_sparse_categorical_accuracy: 0.0556
# Epoch 6/50
# 857/857 [==============================] - ETA: 0s - loss: 13.1779 - sparse_categorical_accuracy: 0.1003
# Epoch 00006: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch06.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 13.1779 - sparse_categorical_accuracy: 0.1003 - val_loss: 17.9517 - val_sparse_categorical_accuracy: 0.0736
# Epoch 7/50
# 857/857 [==============================] - 450s 525ms/step - loss: 11.4149 - sparse_categorical_accuracy: 0.1394 - val_loss: 17.3990 - val_sparse_categorical_accuracy: 0.0902
# Epoch 8/50
# 857/857 [==============================] - ETA: 0s - loss: 9.8615 - sparse_categorical_accuracy: 0.1869
# Epoch 00008: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch08.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 9.8615 - sparse_categorical_accuracy: 0.1869 - val_loss: 16.9397 - val_sparse_categorical_accuracy: 0.1039
# Epoch 9/50
# 857/857 [==============================] - 450s 525ms/step - loss: 8.4632 - sparse_categorical_accuracy: 0.2438 - val_loss: 16.5733 - val_sparse_categorical_accuracy: 0.1162
# Epoch 10/50
# 857/857 [==============================] - ETA: 0s - loss: 7.1945 - sparse_categorical_accuracy: 0.3157
# Epoch 00010: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch10.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 7.1945 - sparse_categorical_accuracy: 0.3157 - val_loss: 16.2113 - val_sparse_categorical_accuracy: 0.1266
# Epoch 11/50
# 857/857 [==============================] - 450s 525ms/step - loss: 6.0759 - sparse_categorical_accuracy: 0.3975 - val_loss: 15.9227 - val_sparse_categorical_accuracy: 0.1350
# Epoch 12/50
# 857/857 [==============================] - ETA: 0s - loss: 5.0836 - sparse_categorical_accuracy: 0.4880
# Epoch 00012: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch12.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 5.0836 - sparse_categorical_accuracy: 0.4880 - val_loss: 15.6754 - val_sparse_categorical_accuracy: 0.1435
# Epoch 13/50
# 857/857 [==============================] - 450s 525ms/step - loss: 4.1938 - sparse_categorical_accuracy: 0.5818 - val_loss: 15.4455 - val_sparse_categorical_accuracy: 0.1507
# Epoch 14/50
# 857/857 [==============================] - ETA: 0s - loss: 3.4209 - sparse_categorical_accuracy: 0.6788
# Epoch 00014: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch14.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 3.4209 - sparse_categorical_accuracy: 0.6788 - val_loss: 15.2516 - val_sparse_categorical_accuracy: 0.1612
# Epoch 15/50
# 857/857 [==============================] - 450s 525ms/step - loss: 2.7556 - sparse_categorical_accuracy: 0.7751 - val_loss: 15.0774 - val_sparse_categorical_accuracy: 0.1699
# Epoch 16/50
# 857/857 [==============================] - ETA: 0s - loss: 2.1929 - sparse_categorical_accuracy: 0.8623
# Epoch 00016: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch16.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 2.1929 - sparse_categorical_accuracy: 0.8623 - val_loss: 14.9324 - val_sparse_categorical_accuracy: 0.1759
# Epoch 17/50
# 857/857 [==============================] - 450s 525ms/step - loss: 1.7335 - sparse_categorical_accuracy: 0.9210 - val_loss: 14.7836 - val_sparse_categorical_accuracy: 0.1815
# Epoch 18/50
# 857/857 [==============================] - ETA: 0s - loss: 1.3267 - sparse_categorical_accuracy: 0.9578
# Epoch 00018: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch18.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 1.3267 - sparse_categorical_accuracy: 0.9578 - val_loss: 14.6644 - val_sparse_categorical_accuracy: 0.1863
# Epoch 19/50
# 857/857 [==============================] - 450s 525ms/step - loss: 1.0075 - sparse_categorical_accuracy: 0.9754 - val_loss: 14.5353 - val_sparse_categorical_accuracy: 0.1909
# Epoch 20/50
# 857/857 [==============================] - ETA: 0s - loss: 0.7725 - sparse_categorical_accuracy: 0.9838
# Epoch 00020: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch20.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 0.7725 - sparse_categorical_accuracy: 0.9838 - val_loss: 14.4207 - val_sparse_categorical_accuracy: 0.1949
# Epoch 21/50
# 857/857 [==============================] - 450s 525ms/step - loss: 0.5824 - sparse_categorical_accuracy: 0.9881 - val_loss: 14.2798 - val_sparse_categorical_accuracy: 0.1978
# Epoch 22/50
# 857/857 [==============================] - ETA: 0s - loss: 0.4440 - sparse_categorical_accuracy: 0.9889
# Epoch 00022: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch22.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 0.4440 - sparse_categorical_accuracy: 0.9889 - val_loss: 14.1888 - val_sparse_categorical_accuracy: 0.2009
# Epoch 23/50
# 857/857 [==============================] - 450s 525ms/step - loss: 0.3490 - sparse_categorical_accuracy: 0.9904 - val_loss: 14.0791 - val_sparse_categorical_accuracy: 0.2066
# Epoch 24/50
# 857/857 [==============================] - ETA: 0s - loss: 0.2927 - sparse_categorical_accuracy: 0.9896
# Epoch 00024: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch24.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 0.2927 - sparse_categorical_accuracy: 0.9896 - val_loss: 13.9978 - val_sparse_categorical_accuracy: 0.2085
# Epoch 25/50
# 857/857 [==============================] - 450s 525ms/step - loss: 0.2447 - sparse_categorical_accuracy: 0.9907 - val_loss: 13.9617 - val_sparse_categorical_accuracy: 0.2121
# Epoch 26/50
# 857/857 [==============================] - ETA: 0s - loss: 0.2368 - sparse_categorical_accuracy: 0.9891
# Epoch 00026: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch26.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9891 - val_loss: 13.8786 - val_sparse_categorical_accuracy: 0.2153
# Epoch 27/50
# 857/857 [==============================] - 450s 525ms/step - loss: 0.2139 - sparse_categorical_accuracy: 0.9892 - val_loss: 13.8378 - val_sparse_categorical_accuracy: 0.2175
# Epoch 28/50
# 857/857 [==============================] - ETA: 0s - loss: 0.2240 - sparse_categorical_accuracy: 0.9874
# Epoch 00028: saving model to /home/yamaguchi-milkcocholate/Shopee/notebooks/../results/monitor/fold-0/Bert_123_epoch28.h5
# 857/857 [==============================] - 452s 527ms/step - loss: 0.2240 - sparse_categorical_accuracy: 0.9874 - val_loss: 13.8339 - val_sparse_categorical_accuracy: 0.2171
# Epoch 29/50
# 857/857 [==============================] - 450s 525ms/step - loss: 0.2343 - sparse_categorical_accuracy: 0.9865 - val_loss: 13.8868 - val_sparse_categorical_accuracy: 0.2136
# Epoch 30/50
# 373/857 [============>.................] - ETA: 3:54 - loss: 0.1785 - sparse_categorical_accuracy: 0.9894
